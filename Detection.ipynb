# %% [markdown]
# <a href="https://colab.research.google.com/github/ImranRiazChohan/PersonDetection-Using-Yolov5/blob/main/Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import cv2

# %%
# !pip install -q roboflow
# from roboflow import Roboflow
# rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")

# from roboflow import Roboflow
# rf = Roboflow(api_key="2TorCZggGToyUjZJQGhv")
# project = rf.workspace("detection-qskiw").project("persondetection-qfgun")
# dataset = project.version("2").download("yolov5")

# %%
# %cat {dataset.location}/data.yaml

# %%
# define number of classes based on YAML
# import yaml
# with open(dataset.location + "/data.yaml", 'r') as stream:
#     num_classes = str(yaml.safe_load(stream)['nc'])
# print(num_classes)

# %%
# weightpath="/content/PersonDetection-2/best (1).pt"

# %%
# import torch
# import numpy as np
# import pandas as pd

# model=torch.hub.load('ultralytics/yolov5', 'custom', path='/content/PersonDetection-2/best (1).pt', force_reload=True)

# %%
# import glob
# from IPython.display import Image, display

# for imageName in glob.glob('/content/PersonDetection-2/test/images/WhatsApp-Video-2022-04-15-at-4_57_04-PM_mp4-101_jpg.rf.408ba7820aa32bcd91dd05c5695f963b.jpg'): #assuming JPG
#     display(Image(filename=imageName))
#     print("\n")

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

# import torch
# from yolov5 import utils
# display = utils.notebook_init()  # checks

# %%
# !python detect.py --weights /content/PersonDetection-2/best.pt --img 416 --conf 0.4 --source /content/PersonDetection-2/test/images

#ye command hi detection ke liye use hogi ab issey opencv pe kee use karein? iska nikalo kahin se answer ya logic lagao koi ?

# %%
# display.Image(filename='/content/yolov5/runs/detect/exp2/WhatsApp-Video-2022-04-15-at-4_57_04-PM_mp4-42_jpg.rf.5677581efc4edaa6b037f9065a68035e.jpg', width=600)

# %%
###### Ye Main Kaaam Hai 

#yahan se Start krna hai

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12847, done.
# remote: Total 12847 (delta 0), reused 0 (delta 0), pack-reused 12847
# Receiving objects: 100% (12847/12847), 11.82 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (8929/8929), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 13.1 MB/s

# %%
# !pip install -q roboflow
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")

from roboflow import Roboflow
rf = Roboflow(api_key="2TorCZggGToyUjZJQGhv")
project = rf.workspace("detection-qskiw").project("persondetection-qfgun")
dataset = project.version("2").download("yolov5")
# Out:
#      |████████████████████████████████| 145 kB 8.3 MB/s
#      |████████████████████████████████| 178 kB 64.6 MB/s
#      |████████████████████████████████| 1.1 MB 62.8 MB/s
#      |████████████████████████████████| 67 kB 3.6 MB/s
#      |████████████████████████████████| 54 kB 3.4 MB/s
#      |████████████████████████████████| 138 kB 48.9 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=roboflow-yolov5
# ...

# %%
# !python detect.py --weights /content/PersonDetection-2/best.pt --img 416 --conf 0.40 --source /content/PersonDetection-2/test/images
# Out:
# detect: weights=['/content/PersonDetection-2/best.pt'], source=/content/PersonDetection-2/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 232 layers, 7249215 parameters, 0 gradients
# image 1/11 /content/PersonDetection-2/test/images/WhatsApp-Video-2022-04-15-at-4_57_04-PM_mp4-101_jpg.rf.408ba7820aa32bcd91dd05c5695f963b.jpg: 416x416 1 Saad, Done. (0.347s)
# image 2/11 /content/PersonDetection-2/test/images/WhatsApp-Video-2022-04-15-at-4_57_04-PM_mp4-18_jpg.rf.fa647c6ad80cf407f119f3d814246f3b.jpg: 416x416 1 Saad, Done. (0.263s)
# ...

# %%
# !python detect.py --weights /content/PersonDetection-2/best.pt --data /content/PersonDetection-2/data.yaml --conf 0.40 --source /content/video2.mp4
# Out:
# detect: weights=['/content/PersonDetection-2/best.pt'], source=/content/video2.mp4, data=/content/PersonDetection-2/data.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 232 layers, 7249215 parameters, 0 gradients
# video 1/1 (1/1025) /content/video2.mp4: 640x384 1 Saad, Done. (0.016s)
# video 1/1 (2/1025) /content/video2.mp4: 640x384 1 Jawad, 1 Saad, Done. (0.012s)
# video 1/1 (3/1025) /content/video2.mp4: 640x384 1 Saad, Done. (0.012s)
# video 1/1 (4/1025) /content/video2.mp4: 640x384 1 Saad, Done. (0.012s)
# ...
